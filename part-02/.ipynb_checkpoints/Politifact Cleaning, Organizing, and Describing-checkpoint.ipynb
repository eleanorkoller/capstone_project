# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
plt.style.use('fivethirtyeight')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### TASK 1: Find and Clean Your Data: Source and format the required data for your project.
#
# This task required us to:
# - Create a database
# - Create a data dictionary
#
# I have already created the database with the notebook [Obtaining Politifact Dataframe](Obtaining Politifact Dataframe.ipynb), which I've kept in a separate notebook because it's a little tedious to read through. (Using the API was really time-consuming, so I performed the scraping repeatedly in little chunks whenever I had free time -- most of the notebook is just running the exact same code but with different numbers and re-saving the dataframe as a csv.  It's not very interesting!)
#
# Below, I've loaded the data into this notebook and created a data dictionary.

# %%
#here is the data:
df = pd.read_csv('first_17500_csv', index_col=0)

# %%
df.head()
# Out:
#     edition                                          statement statement_type  \
# 0     Texas  <p>\r\n\t&quot;The attorney general requires t...          Claim
# 1  National  <p>President Clinton &quot;reduced the scale o...          Claim
# 2  National  "New Mexico was 46th in teacher pay (when he w...          Claim
# 3  National  "I used tax cuts to help create over 80,000 jo...          Claim
# 4  National  New Mexico moved "up to" sixth in the nation i...          Claim
#
#                       statement_context                speaker speaker_party  \
# 0                   in a Web site video  Barbara Ann Radnofsky      Democrat
# 1  a Republican debate in Orlando, Fla.            Mitt Romney    Republican
# 2                              a TV ad.        Bill Richardson      Democrat
# 3                              a TV Ad.        Bill Richardson      Democrat
# 4                              a TV Ad.        Bill Richardson      Democrat
#
#        speaker_job              subject          ruling        date
# 0              NaN                Crime  Pants on Fire!  2009-10-22
# 1  Former governor             Military       Half-True  2007-10-21
# 2         Governor            Education     Mostly True  2007-05-10
# 3         Governor                Taxes     Mostly True  2007-05-10
# 4         Governor  Job Accomplishments     Mostly True  2007-05-10

# %%
df.shape
# Out:
# (14135, 10)

# %%
df.describe()
# Out:
#          edition                            statement statement_type  \
# count      14135                                14135          14135
# unique        25                                14120              3
# top     National  <p>On a cap-and-trade plan.</p>\r\n          Claim
# freq        4724                                    3          12347
#
#        statement_context       speaker speaker_party speaker_job  subject  \
# count              13999         14135         14135        9954    14135
# unique              5543          3666            25        1447      146
# top         an interview  Barack Obama    Republican   President  Economy
# freq                 345           618          6230        1110     1180
#
#            ruling        date
# count       14135       14135
# unique          9        3239
# top     Half-True  2011-10-11
# freq         2779          26

# %% [markdown]
# #### Data Dictionary:
#
# edition: indicates from what edition of Politifact the reporting comes (eg National for country-wide politics, Florida for Florida-state-level politics, or PunditFact for political discussions in the media).
#
# statement: the actual statement that Politifact evaluated.  The majority of these are direct quotes, but some have direct quotes embedded into a paraphrased statement for ease of understanding.
#
# statement_type: the classification of the statement as a Claim (a general assertion), an Attack (against a particular person), or a Flip (the last of which rates not whether the statement is true or not, but rather whether it represents a change from the speaker's previous position).
#
# statement_context: where the statement came from (eg a speech, a tweet, or an ad, to give a few examples)
#
# speaker: the name of the person who gave the statement
#
# speaker_party: the party of the person who gave the statement, usually either Republican or Democrat.  Sometimes, when appropriate, this is actually the organization that the speaker represents rather than their political affiliation (for example, 'Newsmaker', 'Government body', or 'Education official').
#
# speaker_job: the job of the person who gave the statement (for example, 'President' or 'Governor').
#
# subject: the topic of the statement (for example, 'Military' or 'Education').
#
# ruling: the Politifact judgement about the truthfulness of the statement (except for Flips, as noted above).
#
# date: the date on which the statement was given

# %% [markdown]
# ### Task 2: Perform preliminary data munging and cleaning of your data: organize your data relevant to your project goals.
#    - Review data to verify initial assumptions
#    - Clean and munge data as necessary

# %% [markdown]
# There aren't that many 'Flip' statements, and they don't really fit my purposes (I'm not interested in looking at whether someone has changed position, just whether they're telling the truth or not), so I'm going to eliminate those from my dataset.

# %%
df['statement_type'].value_counts()
# Out:
# Claim     12347
# Attack     1570
# Flip        218
# Name: statement_type, dtype: int64

# %%
df = df.loc[df['statement_type']!='Flip']

# %%
df.shape
# Out:
# (13917, 10)

# %%
df['statement_type'].unique()
# Out:
# array(['Claim', 'Attack'], dtype=object)

# %% [markdown]
# I don't know if I want to look at only the National edition or not, so I'm going to look at the breakdown for what the different editions are and how many observations are associated with each.

# %%
df['edition'].value_counts()
# Out:
# National               4658
# Florida                1429
# Texas                  1353
# Wisconsin              1259
# PunditFact              931
# Georgia                 864
# Ohio                    591
# Rhode Island            544
# Virginia                538
# New Jersey              393
# Oregon                  389
# New Hampshire           155
# California              119
# Global News Service      91
# North Carolina           87
# New York                 87
# Missouri                 87
# Pennsylvania             80
# Tennessee                76
# Illinois                 62
# Nevada                   41
# Arizona                  38
# Colorado                 30
# Iowa                     12
# NBC                       3
# Name: edition, dtype: int64

# %%
df.loc[df['edition']=='PunditFact'].head()
# Out:
#          edition                                          statement  \
# 7811  PunditFact  <p>&quot;1 percent of candidates that (the Nat...
# 8011  PunditFact  <p>&quot;The insurance industry is actually ru...
# 8012  PunditFact  <p>&quot;Even after Obamacare is fully impleme...
# 8014  PunditFact  <p>The average fast food worker is 29, and mos...
# 8017  PunditFact  <p>Congress &quot;is bewildered at the scope a...
#
#      statement_type                                 statement_context  \
# 7811          Claim                 a discussion on CNN's "Crossfire"
# 8011          Claim        comments on Fox News Channel's "The Five."
# 8012          Claim             a column in the "Wall Street Journal"
# 8014          Claim     comments on HBO's "Real Time with Bill Maher"
# 8017          Claim  in comments on Comedy Central's "The Daily Show"
#
#              speaker speaker_party                               speaker_job  \
# 7811       Van Jones      Democrat              Co-host of CNN's "Crossfire"
# 8011     Dana Perino    Republican  Co-host on Fox News Channel's "The Five"
# 8012  Suzanne Somers          None                                   Actress
# 8014      Bill Maher   Independent         Host of Real Time with Bill Maher
# 8017     Jon Stewart          None                                       NaN
#
#                subject       ruling        date
# 7811  Campaign Finance        False  2013-09-13
# 8011       Health Care        False  2013-10-31
# 8012       Health Care         True  2013-11-28
# 8014              Jobs  Mostly True  2013-10-25
# 8017    Foreign Policy         True  2013-10-30

# %%
df.loc[df['edition']=='Global News Service'].head()
# Out:
#                    edition                                          statement  \
# 11234  Global News Service  <p>&quot;Bioweapon! Zika virus is being spread...
# 11258  Global News Service  <p>&quot;People think AIDS is done --&nbsp;it&...
# 11259  Global News Service  <p>&quot;Obama spent $7 billion to bring elect...
# 11294  Global News Service  <p>&quot;The most likely triggering cause of (...
# 11300  Global News Service  <p>&quot;The richest 80 people in the world ow...
#
#       statement_type                         statement_context  \
# 11234          Claim                       comments on YouTube
# 11258          Claim       an interview with the "Irish Times"
# 11259          Claim       an article on the Frontpage website
# 11294          Claim  an article posted on the group's website
# 11300          Claim                                   a video
#
#                                     speaker speaker_party   speaker_job  \
# 11234                           Viral image          None           NaN
# 11258                                  Bono          None           NaN
# 11259                     Daniel Greenfield    Republican           NaN
# 11294  Centre for Research on Globalization          None           NaN
# 11300                        Bernie Sanders   Independent  U.S. Senator
#
#              subject          ruling        date
# 11234        Animals  Pants on Fire!  2016-01-27
# 11258  Public Health     Mostly True  2016-01-24
# 11259         Energy  Pants on Fire!  2015-07-30
# 11294  Public Health           False  2016-02-04
# 11300        Economy     Mostly True  2016-02-07

# %%
df.loc[df['edition']=='NBC']
# Out:
#       edition                                          statement  \
# 11452     NBC  <p>&quot;Our campaign depends on small donatio...
# 11824     NBC  <p>&quot;More businesses went out of business ...
# 11883     NBC  <p>Even among &quot;second and third generatio...
#
#       statement_type                              statement_context  \
# 11452          Claim  a victory speech after the March 15 primaries
# 11824          Claim   an interview on NBC's "Meet the Press Daily"
# 11883          Claim       an interview with Fox News' Sean Hannity
#
#                speaker speaker_party             speaker_job  \
# 11452  Hillary Clinton      Democrat  Presidential candidate
# 11824     David Perdue    Republican   U.S. Senate candidate
# 11883     Donald Trump    Republican               President
#
#                 subject        ruling        date
# 11452  Campaign Finance  Mostly False  2016-03-15
# 11824           Economy         False  2016-06-02
# 11883         Diversity         False  2016-06-15

# %% [markdown]
# I understand PunditFact and Global News Service as distinct and potentially valuable categories (the former dealing with statements made in the media, and the latter dealing primarily with events or people not within the space of American politics), but I don't think I understand what 'NBC' is all about (one of them seems to be from an NBC interview, but then one of them is from a Fox News interview, so...?).  Given that all three of the observations relate to national-level politics and are delivered by national-level politicians, I'm going to incorporate them into the 'National' edition category.
#
# Otherwise, I'm going to retain all of the editions, but I'm going to add an additional column indicating whether the edition is National, State, Media, or Global.

# %%
df.loc[df['edition']=='NBC', 'edition'] = 'National'

# %%
df.loc[df['edition']=='NBC']
# Out:
# Empty DataFrame
# Columns: [edition, statement, statement_type, statement_context, speaker, speaker_party, speaker_job, subject, ruling, date]
# Index: []

# %%
df['edition_type']=df['edition'].map(lambda x: 'National' if x=='National' else 'Media' if x=='PunditFact' else 'Global' if x=='Global News Service' else 'State')

# %%
df['edition_type'].value_counts()
# Out:
# State       8234
# National    4661
# Media        931
# Global        91
# Name: edition_type, dtype: int64

# %%
df.head()
# Out:
#     edition                                          statement statement_type  \
# 0     Texas  <p>\r\n\t&quot;The attorney general requires t...          Claim
# 1  National  <p>President Clinton &quot;reduced the scale o...          Claim
# 2  National  "New Mexico was 46th in teacher pay (when he w...          Claim
# 3  National  "I used tax cuts to help create over 80,000 jo...          Claim
# 4  National  New Mexico moved "up to" sixth in the nation i...          Claim
#
#                       statement_context                speaker speaker_party  \
# 0                   in a Web site video  Barbara Ann Radnofsky      Democrat
# 1  a Republican debate in Orlando, Fla.            Mitt Romney    Republican
# 2                              a TV ad.        Bill Richardson      Democrat
# 3                              a TV Ad.        Bill Richardson      Democrat
# 4                              a TV Ad.        Bill Richardson      Democrat
#
#        speaker_job              subject          ruling        date  \
# 0              NaN                Crime  Pants on Fire!  2009-10-22
# 1  Former governor             Military       Half-True  2007-10-21
# 2         Governor            Education     Mostly True  2007-05-10
# 3         Governor                Taxes     Mostly True  2007-05-10
# 4         Governor  Job Accomplishments     Mostly True  2007-05-10
#
#   edition_type
# 0        State
# 1     National
# 2     National
# 3     National
# 4     National

# %% [markdown]
# Next I want to have a look at the rulings category, to determine what sort of rulings I have, and how many of each there are. This will be my target variable, and I think I'll probably want to create a new binary variable that tries to capture either 'True' or 'False'.

# %%
df['ruling'].value_counts()
# Out:
# Half-True         2779
# Mostly True       2686
# False             2619
# Mostly False      2322
# True              2149
# Pants on Fire!    1350
# Full Flop           10
# Half Flip            2
# Name: ruling, dtype: int64

# %%
df.loc[df['ruling']=='Full Flop']
# Out:
#          edition                                          statement  \
# 828     National  <p>U.S. Senate Majority Leader Harry Reid on w...
# 1116    National  <p>On whether the governor of Massachusetts sh...
# 3308    National  <p>\r\n\tOn the president unilaterally authori...
# 3313    National  <p>\r\n\tOn whether the United States should i...
# 3629    National  <p>\r\n\tOn whether he would vote for the budg...
# 10262      Texas  <p>On reauthorization of Export-Import Bank.</...
# 10867  Wisconsin   <p>On support for the Export-Import Bank</p>\r\n
# 13041   National  <p>On leaks and the release of secret informat...
# 13051  Wisconsin  <div>On whether the Senate should vote in a ti...
# 13867   National  <p>On whether higher federal deficits are acce...
#
#       statement_type                                  statement_context  \
# 828            Claim                                 public statements.
# 1116           Claim                             votes in 2004 and 2009
# 3308           Claim               an interview with the "Boston Globe"
# 3313           Claim                               televised interviews
# 3629           Claim                   a public appearance and an op-ed
# 10262          Claim                                     an oped column
# 10867          Claim              On support for the Export-Import Bank
# 13041          Claim  comments during and after the 2016 presidentia...
# 13051          Claim                            various public comments
# 13867          Claim                  an interview on "Fox News Sunday"
#
#                           speaker speaker_party  \
# 828                    Harry Reid      Democrat
# 1116    Massachusetts legislature      Democrat
# 3308                 Barack Obama      Democrat
# 3313                Newt Gingrich    Republican
# 3629                  Scott Brown    Republican
# 10262                  Rick Perry    Republican
# 10867                 Ron Johnson    Republican
# 13041                Donald Trump    Republican
# 13051               Tammy Baldwin      Democrat
# 13867               Mick Mulvaney    Republican
#
#                                            speaker_job            subject  \
# 828                           Senate Democratic Leader       Legal Issues
# 1116                                       Making laws          Elections
# 3308                                         President     Foreign Policy
# 3313                                               NaN     Foreign Policy
# 3629                                               NaN            Deficit
# 10262                            U.S. Energy Secretary              Trade
# 10867                                              NaN              Trade
# 13041                                        President  Homeland Security
# 13051                              U.S. Representative       Legal Issues
# 13867  Director of the Office of Management and Budget               Debt
#
#           ruling        date edition_type
# 828    Full Flop  2009-01-13     National
# 1116   Full Flop  2009-09-22     National
# 3308   Full Flop  2007-12-07     National
# 3313   Full Flop  2011-03-23     National
# 3629   Full Flop  2011-05-23     National
# 10262  Full Flop  2015-05-05        State
# 10867  Full Flop  2015-10-20        State
# 13041  Full Flop  2017-02-16     National
# 13051  Full Flop  2017-02-02        State
# 13867  Full Flop  2017-10-01     National

# %% [markdown]
# As explained before, I'm not interested in whether someone has changed their position, just whether the statement is true, so I'm going to get rid of the observations with 'Full Flop' and 'Half Flip' rulings.

# %%
df = df.loc[(df['ruling']!='Full Flop')&(df['ruling']!='Half Flip')]

# %%
df.shape
# Out:
# (13905, 11)

# %% [markdown]
# I'm not entirely sure what to do about the 'Half-True' ruling, if I'm trying to create a binary variable.  I looked at the write-up for five of these cases on Politifact.com as well as their rating system, given [here](http://www.politifact.com/truth-o-meter/article/2011/feb/21/principles-truth-o-meter/), which describes the criteria for a Half-True ruling as, "The statement is partially accurate but leaves out important details or takes things out of context."  The tone of the write-ups seems to be that the statements deemed 'Half-True' are more true than false, on balance, and it makes things neat, with three 'True' rulings ('True', 'Mostly True', and 'Half-True') and three 'False' rulings ('Mostly False', 'False', and 'Pants on Fire!').

# %%
df['ruling'].unique()
# Out:
# array(['Pants on Fire!', 'Half-True', 'Mostly True', 'True', 'False',
#        'Mostly False'], dtype=object)

# %%
def trueorfalse(x):
    if x=='True': y='True'
    elif x=='Mostly True': y='True'
    elif x=='Half-True': y='True'
    elif x=='Mostly False': y='False'
    elif x=='False': y='False'
    elif x=='Pants on Fire!': y='False'
    return y

df['binary_ruling'] = df['ruling'].map(trueorfalse)

# %%
df['binary_ruling'].value_counts()
# Out:
# True     7614
# False    6291
# Name: binary_ruling, dtype: int64

# %% [markdown]
# A lot of the statements have various characters at the beginning for formatting on the webpage that shouldn't be there for our analysis, and I'm going to try to strip those characters away (although it's hard to see all of their formulations, so I'm not sure if I'll get all of them).

# %%
df.tail(50)
# Out:
#           edition                                          statement  \
# 14085   Wisconsin  Under the House Republican tax plan, in Wiscon...
# 14086       Texas  "Earlier this year, Hurricane Harvey left more...
# 14087    National  "We're ... getting into the pool of the 100 mi...
# 14088    National  Says the concealed carry bill would allow resi...
# 14089    Missouri  "In the current law, if you report harassment,...
# 14090    National  Says "Obama's deadliest cover-up (in an explos...
# 14091    National  "Gloria Allred Accuser **ADMITS** She Tampered...
# 14092  PunditFact  Says Russian President Vladimir Putingota stan...
# 14093  PunditFact  "The FBI has become America's secret police......
# 14094    Illinois  "I released way more (tax) information than Br...
# 14095  PunditFact  "Breaking: woman says she was offered big mone...
# 14096  PunditFact  "Roy Moore's accuser arrested and charged with...
# 14097    National  "Black homeownership just hit the highest leve...
# 14098   Wisconsin  "Under Trump's new tax plan ... 99.8% of Ameri...
# 14099  PunditFact  "Facebook picks sides in Alabama Senate race ....
# 14100  PunditFact  "Breaking: Trump fires deputy attorney general...
# 14101  PunditFact       A Colgate toothpaste is subject to "recall."
# 14102    National  "Even with full control of the House, Senate a...
# 14103  PunditFact  "Morgue employee cremated by mistake while tak...
# 14104  PunditFact  "Now it's official: FDA announced that vaccine...
# 14105  PunditFact  "Update: van full of illegals caught voting at...
# 14106     Florida  The House tax bill has "a lot more permanent r...
# 14107    Illinois  "The candidates controlled by Madigan, all of ...
# 14108    Missouri  "In Missouri, there are still (FEMA) cases pen...
# 14109  California  "This new gas tax does not increase (road) cap...
# 14110    National  Says Donald Trump "has not apologized" for com...
# 14111    New York  On the Republican tax plan: "Unfortunately, th...
# 14112   Wisconsin  The House tax plan "would provide permanent ta...
# 14113    National  Says the Obama administration purged "training...
# 14114  PunditFact  Says there won't be a recount in Alabama becau...
# 14115   Wisconsin  The 1986 tax reform approved under Ronald Reag...
# 14116    Missouri  Missouri "is leading the country when it comes...
# 14117    Missouri  "Officials at Hyperloop One have referred to t...
# 14118    Missouri  Missouri is one of "13 states this year have s...
# 14119  PunditFact  "UPDATE: 'Thousands' voted for Doug Jones in A...
# 14120  PunditFact  "Update: Chuck Schumer's steamy affair with a ...
# 14121  PunditFact  Says Marco Rubio tweeted a verse from the New ...
# 14122    National  Says Sen. Mitch McConnell's delay in seating A...
# 14123  PunditFact  "Alabama state police arrest 3 poll workers in...
# 14124  PunditFact  "Law passed: All child support in the United S...
# 14125   Wisconsin  Wisconsin's state court agency "basically" has...
# 14126  PunditFact  "Breaking: Muslim New Jersey Mayor just banned...
# 14127  California  BREAKING: Illegal Muslim From Iran Arrested Fo...
# 14128    New York  "The truth is this tax [plan] raises middle-cl...
# 14129    National  Says of the diversity visa lottery program, "t...
# 14130    National  "We essentially repealed Obamacare because we ...
# 14131    National  In April, "the vast majority will be (filling ...
# 14132       Texas  Says the Texas General Land Office led by Geor...
# 14133       Texas  Says Texas Department of Public Safety numbers...
# 14134    Missouri  "Fentanyl is now killing more Americans than h...
#
#       statement_type                                  statement_context  \
# 14085          Claim                                       an interview
# 14086          Claim           a guest editorial in Drilling Contractor
# 14087          Claim                                  a cabinet meeting
# 14088          Claim                                            a tweet
# 14089          Claim                   an interview on "Meet the Press"
# 14090          Claim                                      a campaign ad
# 14091          Claim                                        a blog post
# 14092          Claim                                      a chain email
# 14093          Claim                          an interview on "Hannity"
# 14094          Claim                                  a candidate forum
# 14095          Claim                                         a headline
# 14096          Claim                                a fake news website
# 14097          Claim                         a rally in Pensacola, Fla.
# 14098         Attack                                            a tweet
# 14099          Claim                                        a web story
# 14100          Claim                                         a headline
# 14101          Claim                            an article on a website
# 14102          Claim                 a statement released by her office
# 14103          Claim                                         a headline
# 14104          Claim                            an article on a website
# 14105          Claim                                         a headline
# 14106          Claim                             a television interview
# 14107          Claim                                 a press conference
# 14108          Claim                                     a news release
# 14109          Claim              a Repeal the Gas Tax campaign article
# 14110          Claim                   an interview on 'Meet the Press'
# 14111          Claim                             a local news interview
# 14112          Claim                               a House floor speech
# 14113          Claim                          a House committee hearing
# 14114          Claim               a broadcast of the "Alex Jones Show"
# 14115          Claim                                       an interview
# 14116          Claim                                           a speech
# 14117          Claim             a Kansas City Business Journal article
# 14118          Claim                       a speech in St. Charles, Mo.
# 14119          Claim                                        a blog post
# 14120          Claim                                         a headline
# 14121          Claim                            an article on a website
# 14122          Claim                   an article posted on the website
# 14123          Claim                                         a headline
# 14124          Claim                                         a headline
# 14125          Claim                                       an interview
# 14126         Attack                                         a headline
# 14127          Claim                                         a headline
# 14128          Claim                                            Buffalo
# 14129          Claim                                           a speech
# 14130          Claim                                           a speech
# 14131          Claim                    an interview on "Fox & Friends"
# 14132          Claim  an interview with Austin American-Statesman co...
# 14133          Claim                   a Dallas Morning News news story
# 14134          Claim                                    a press release
#
#                          speaker   speaker_party  \
# 14085                  Paul Ryan      Republican
# 14086                Ryan Sitton      Republican
# 14087               Donald Trump      Republican
# 14088              Brendan Boyle        Democrat
# 14089                  Roy Blunt      Republican
# 14090            Don Blankenship      Republican
# 14091                   Bloggers            None
# 14092                Chain email            None
# 14093              Gregg Jarrett      Republican
# 14094                JB Pritzker        Democrat
# 14095              Evening World            None
# 14096                   Bloggers            None
# 14097               Donald Trump      Republican
# 14098           Kelda Helen Roys        Democrat
# 14099         The Gateway Pundit            None
# 14100    HoustonChronicle-tv.com            None
# 14101                Shared This            None
# 14102              Nancy  Pelosi        Democrat
# 14103   worldnewsdailyreport.com            None
# 14104           truthcommand.com            None
# 14105          nofakenews-online            None
# 14106             Carlos Curbelo      Republican
# 14107               Bruce Rauner      Republican
# 14108             Vicky Hartzler      Republican
# 14109               Travis Allen      Republican
# 14110             Bernie Sanders     Independent
# 14111             Claudia Tenney      Republican
# 14112                 Gwen Moore        Democrat
# 14113                Scott Perry      Republican
# 14114                 Alex Jones  Talk show host
# 14115                  Paul Ryan      Republican
# 14116                  Roy Blunt      Republican
# 14117            Patrick McKenna            None
# 14118               Donald Trump      Republican
# 14119                   Bloggers            None
# 14120               USA In Front            None
# 14121          Verified Politics            None
# 14122          Verified Politics            None
# 14123        American Revolution            None
# 14124                tmzbreaking            None
# 14125              Matt Adamczyk      Republican
# 14126   TheLastLineOfDefense.org            None
# 14127               USA In Front            None
# 14128         Kirsten Gillibrand        Democrat
# 14129               Donald Trump      Republican
# 14130               Donald Trump      Republican
# 14131               Ivanka Trump            None
# 14132            Jerry Patterson      Republican
# 14133                Lupe Valdez        Democrat
# 14134           Claire McCaskill        Democrat
#
#                                              speaker_job              subject  \
# 14085                                U.S. Representative             Children
# 14086                     President and CEO, PinnacleAIS              Housing
# 14087                                          President              Economy
# 14088                                                NaN                 Guns
# 14089                                            Senator  Congressional Rules
# 14090                                                NaN            Elections
# 14091                                                NaN            Fake news
# 14092                                                NaN          Immigration
# 14093                                                NaN                Crime
# 14094                            Gubernatorial candidate     Campaign Finance
# 14095                                                NaN            Elections
# 14096                                                NaN            Elections
# 14097                                          President            Diversity
# 14098                                                NaN                Taxes
# 14099                                                NaN            Fake news
# 14100                                                NaN            Fake news
# 14101                                                NaN            Fake news
# 14102                              House Minority Leader              Economy
# 14103                                                NaN            Fake news
# 14104                                                NaN               Autism
# 14105                                                NaN            Elections
# 14106                     Miami-Dade school board member                Taxes
# 14107                                           Governor            Elections
# 14108                                U.S. Representative   Natural Disasters
# 14109                                                NaN           Gas Prices
# 14110                                       U.S. Senator  Candidate Biography
# 14111                                      Assemblywoman                Taxes
# 14112                  U.S. House member -- 4th District             Families
# 14113                                     Representative            Terrorism
# 14114                                                NaN            Elections
# 14115                                U.S. Representative              History
# 14116                                            Senator          Health Care
# 14117  Director of the Missouri Department of Transpo...       Transportation
# 14118                                          President              Economy
# 14119                                                NaN            Elections
# 14120                                                NaN             Congress
# 14121                                                NaN             Religion
# 14122                                                NaN            Elections
# 14123                                                NaN            Elections
# 14124                                                NaN             Children
# 14125                                                NaN       Infrastructure
# 14126                                                NaN      City Government
# 14127                                                NaN                Crime
# 14128                                       U.S. Senator                Taxes
# 14129                                          President    Homeland Security
# 14130                                          President          Health Care
# 14131                Assistant to President Donald Trump                Taxes
# 14132                     former state land commissioner              Housing
# 14133                      Former sheriff, Dallas County                Crime
# 14134                                       U.S. Senator                Drugs
#
#                ruling        date edition_type binary_ruling
# 14085       Half-True  2017-12-01        State          True
# 14086           False  2017-11-07        State         False
# 14087     Mostly True  2017-12-06     National          True
# 14088           False  2017-12-05     National         False
# 14089       Half-True  2017-11-19        State          True
# 14090  Pants on Fire!  2017-12-03     National         False
# 14091  Pants on Fire!  2017-12-08     National         False
# 14092  Pants on Fire!  2017-12-05        Media         False
# 14093  Pants on Fire!  2017-12-06        Media         False
# 14094           False  2017-12-06        State         False
# 14095  Pants on Fire!  2017-11-13        Media         False
# 14096  Pants on Fire!  2017-12-08        Media         False
# 14097           False  2017-12-08     National         False
# 14098  Pants on Fire!  2017-12-01        State         False
# 14099           False  2017-12-08        Media         False
# 14100  Pants on Fire!  2017-12-08        Media         False
# 14101           False  2017-11-28        Media         False
# 14102    Mostly False  2017-12-08     National         False
# 14103  Pants on Fire!  2017-03-03        Media         False
# 14104  Pants on Fire!  2017-11-21        Media         False
# 14105  Pants on Fire!  2017-12-12        Media         False
# 14106     Mostly True  2017-12-10        State          True
# 14107    Mostly False  2017-12-04        State         False
# 14108     Mostly True  2017-10-30        State          True
# 14109    Mostly False  2017-06-15        State         False
# 14110           False  2017-12-10     National         False
# 14111    Mostly False  2017-12-03        State         False
# 14112       Half-True  2017-11-29        State          True
# 14113       Half-True  2017-11-30     National          True
# 14114  Pants on Fire!  2017-12-13        Media         False
# 14115       Half-True  2017-12-13        State          True
# 14116     Mostly True  2017-10-13        State          True
# 14117       Half-True  2017-10-19        State          True
# 14118           False  2017-11-29        State         False
# 14119  Pants on Fire!  2017-12-13        Media         False
# 14120  Pants on Fire!  2017-12-10        Media         False
# 14121           False  2017-12-09        Media         False
# 14122           False  2017-12-13     National         False
# 14123  Pants on Fire!  2017-12-15        Media         False
# 14124  Pants on Fire!  2016-09-20        Media         False
# 14125     Mostly True  2017-12-15        State          True
# 14126  Pants on Fire!  2017-12-16        Media         False
# 14127  Pants on Fire!  2017-12-11        State         False
# 14128       Half-True  2017-12-15        State          True
# 14129  Pants on Fire!  2017-12-15     National         False
# 14130           False  2017-12-20     National         False
# 14131           False  2017-12-21     National         False
# 14132     Mostly True  2017-12-08        State          True
# 14133       Half-True  2017-07-31        State          True
# 14134       Half-True  2017-11-22        State          True

# %%
def cleanstring(x):
    x = x.replace('<p>\r\n\t','')
    x = x.replace('<p>','')
    x = x.replace('</p>','')
    x = x.replace('<p>&quot;','')
    x = x.replace('&quot;','"')
    x = x.replace('&lsquo;',"'")
    x = x.replace('&rsquo;',"'")
    x = x.replace('<div>','')
    x = x.replace('&nbsp;','')
    x = x.replace('&#39;',"'")
    x = x.replace('&hellip;','...')
    x = x.replace('\r\n','')
    return x
    
df['statement'] = df['statement'].map(cleanstring)

# %%
#this is looking cleaner now!
df.tail(50)
# Out:
#           edition                                          statement  \
# 14085   Wisconsin  Under the House Republican tax plan, in Wiscon...
# 14086       Texas  "Earlier this year, Hurricane Harvey left more...
# 14087    National  "We're ... getting into the pool of the 100 mi...
# 14088    National  Says the concealed carry bill would allow resi...
# 14089    Missouri  "In the current law, if you report harassment,...
# 14090    National  Says "Obama's deadliest cover-up (in an explos...
# 14091    National  "Gloria Allred Accuser **ADMITS** She Tampered...
# 14092  PunditFact  Says Russian President Vladimir Putingota stan...
# 14093  PunditFact  "The FBI has become America's secret police......
# 14094    Illinois  "I released way more (tax) information than Br...
# 14095  PunditFact  "Breaking: woman says she was offered big mone...
# 14096  PunditFact  "Roy Moore's accuser arrested and charged with...
# 14097    National  "Black homeownership just hit the highest leve...
# 14098   Wisconsin  "Under Trump's new tax plan ... 99.8% of Ameri...
# 14099  PunditFact  "Facebook picks sides in Alabama Senate race ....
# 14100  PunditFact  "Breaking: Trump fires deputy attorney general...
# 14101  PunditFact       A Colgate toothpaste is subject to "recall."
# 14102    National  "Even with full control of the House, Senate a...
# 14103  PunditFact  "Morgue employee cremated by mistake while tak...
# 14104  PunditFact  "Now it's official: FDA announced that vaccine...
# 14105  PunditFact  "Update: van full of illegals caught voting at...
# 14106     Florida  The House tax bill has "a lot more permanent r...
# 14107    Illinois  "The candidates controlled by Madigan, all of ...
# 14108    Missouri  "In Missouri, there are still (FEMA) cases pen...
# 14109  California  "This new gas tax does not increase (road) cap...
# 14110    National  Says Donald Trump "has not apologized" for com...
# 14111    New York  On the Republican tax plan: "Unfortunately, th...
# 14112   Wisconsin  The House tax plan "would provide permanent ta...
# 14113    National  Says the Obama administration purged "training...
# 14114  PunditFact  Says there won't be a recount in Alabama becau...
# 14115   Wisconsin  The 1986 tax reform approved under Ronald Reag...
# 14116    Missouri  Missouri "is leading the country when it comes...
# 14117    Missouri  "Officials at Hyperloop One have referred to t...
# 14118    Missouri  Missouri is one of "13 states this year have s...
# 14119  PunditFact  "UPDATE: 'Thousands' voted for Doug Jones in A...
# 14120  PunditFact  "Update: Chuck Schumer's steamy affair with a ...
# 14121  PunditFact  Says Marco Rubio tweeted a verse from the New ...
# 14122    National  Says Sen. Mitch McConnell's delay in seating A...
# 14123  PunditFact  "Alabama state police arrest 3 poll workers in...
# 14124  PunditFact  "Law passed: All child support in the United S...
# 14125   Wisconsin  Wisconsin's state court agency "basically" has...
# 14126  PunditFact  "Breaking: Muslim New Jersey Mayor just banned...
# 14127  California  BREAKING: Illegal Muslim From Iran Arrested Fo...
# 14128    New York  "The truth is this tax [plan] raises middle-cl...
# 14129    National  Says of the diversity visa lottery program, "t...
# 14130    National  "We essentially repealed Obamacare because we ...
# 14131    National  In April, "the vast majority will be (filling ...
# 14132       Texas  Says the Texas General Land Office led by Geor...
# 14133       Texas  Says Texas Department of Public Safety numbers...
# 14134    Missouri  "Fentanyl is now killing more Americans than h...
#
#       statement_type                                  statement_context  \
# 14085          Claim                                       an interview
# 14086          Claim           a guest editorial in Drilling Contractor
# 14087          Claim                                  a cabinet meeting
# 14088          Claim                                            a tweet
# 14089          Claim                   an interview on "Meet the Press"
# 14090          Claim                                      a campaign ad
# 14091          Claim                                        a blog post
# 14092          Claim                                      a chain email
# 14093          Claim                          an interview on "Hannity"
# 14094          Claim                                  a candidate forum
# 14095          Claim                                         a headline
# 14096          Claim                                a fake news website
# 14097          Claim                         a rally in Pensacola, Fla.
# 14098         Attack                                            a tweet
# 14099          Claim                                        a web story
# 14100          Claim                                         a headline
# 14101          Claim                            an article on a website
# 14102          Claim                 a statement released by her office
# 14103          Claim                                         a headline
# 14104          Claim                            an article on a website
# 14105          Claim                                         a headline
# 14106          Claim                             a television interview
# 14107          Claim                                 a press conference
# 14108          Claim                                     a news release
# 14109          Claim              a Repeal the Gas Tax campaign article
# 14110          Claim                   an interview on 'Meet the Press'
# 14111          Claim                             a local news interview
# 14112          Claim                               a House floor speech
# 14113          Claim                          a House committee hearing
# 14114          Claim               a broadcast of the "Alex Jones Show"
# 14115          Claim                                       an interview
# 14116          Claim                                           a speech
# 14117          Claim             a Kansas City Business Journal article
# 14118          Claim                       a speech in St. Charles, Mo.
# 14119          Claim                                        a blog post
# 14120          Claim                                         a headline
# 14121          Claim                            an article on a website
# 14122          Claim                   an article posted on the website
# 14123          Claim                                         a headline
# 14124          Claim                                         a headline
# 14125          Claim                                       an interview
# 14126         Attack                                         a headline
# 14127          Claim                                         a headline
# 14128          Claim                                            Buffalo
# 14129          Claim                                           a speech
# 14130          Claim                                           a speech
# 14131          Claim                    an interview on "Fox & Friends"
# 14132          Claim  an interview with Austin American-Statesman co...
# 14133          Claim                   a Dallas Morning News news story
# 14134          Claim                                    a press release
#
#                          speaker   speaker_party  \
# 14085                  Paul Ryan      Republican
# 14086                Ryan Sitton      Republican
# 14087               Donald Trump      Republican
# 14088              Brendan Boyle        Democrat
# 14089                  Roy Blunt      Republican
# 14090            Don Blankenship      Republican
# 14091                   Bloggers            None
# 14092                Chain email            None
# 14093              Gregg Jarrett      Republican
# 14094                JB Pritzker        Democrat
# 14095              Evening World            None
# 14096                   Bloggers            None
# 14097               Donald Trump      Republican
# 14098           Kelda Helen Roys        Democrat
# 14099         The Gateway Pundit            None
# 14100    HoustonChronicle-tv.com            None
# 14101                Shared This            None
# 14102              Nancy  Pelosi        Democrat
# 14103   worldnewsdailyreport.com            None
# 14104           truthcommand.com            None
# 14105          nofakenews-online            None
# 14106             Carlos Curbelo      Republican
# 14107               Bruce Rauner      Republican
# 14108             Vicky Hartzler      Republican
# 14109               Travis Allen      Republican
# 14110             Bernie Sanders     Independent
# 14111             Claudia Tenney      Republican
# 14112                 Gwen Moore        Democrat
# 14113                Scott Perry      Republican
# 14114                 Alex Jones  Talk show host
# 14115                  Paul Ryan      Republican
# 14116                  Roy Blunt      Republican
# 14117            Patrick McKenna            None
# 14118               Donald Trump      Republican
# 14119                   Bloggers            None
# 14120               USA In Front            None
# 14121          Verified Politics            None
# 14122          Verified Politics            None
# 14123        American Revolution            None
# 14124                tmzbreaking            None
# 14125              Matt Adamczyk      Republican
# 14126   TheLastLineOfDefense.org            None
# 14127               USA In Front            None
# 14128         Kirsten Gillibrand        Democrat
# 14129               Donald Trump      Republican
# 14130               Donald Trump      Republican
# 14131               Ivanka Trump            None
# 14132            Jerry Patterson      Republican
# 14133                Lupe Valdez        Democrat
# 14134           Claire McCaskill        Democrat
#
#                                              speaker_job              subject  \
# 14085                                U.S. Representative             Children
# 14086                     President and CEO, PinnacleAIS              Housing
# 14087                                          President              Economy
# 14088                                                NaN                 Guns
# 14089                                            Senator  Congressional Rules
# 14090                                                NaN            Elections
# 14091                                                NaN            Fake news
# 14092                                                NaN          Immigration
# 14093                                                NaN                Crime
# 14094                            Gubernatorial candidate     Campaign Finance
# 14095                                                NaN            Elections
# 14096                                                NaN            Elections
# 14097                                          President            Diversity
# 14098                                                NaN                Taxes
# 14099                                                NaN            Fake news
# 14100                                                NaN            Fake news
# 14101                                                NaN            Fake news
# 14102                              House Minority Leader              Economy
# 14103                                                NaN            Fake news
# 14104                                                NaN               Autism
# 14105                                                NaN            Elections
# 14106                     Miami-Dade school board member                Taxes
# 14107                                           Governor            Elections
# 14108                                U.S. Representative   Natural Disasters
# 14109                                                NaN           Gas Prices
# 14110                                       U.S. Senator  Candidate Biography
# 14111                                      Assemblywoman                Taxes
# 14112                  U.S. House member -- 4th District             Families
# 14113                                     Representative            Terrorism
# 14114                                                NaN            Elections
# 14115                                U.S. Representative              History
# 14116                                            Senator          Health Care
# 14117  Director of the Missouri Department of Transpo...       Transportation
# 14118                                          President              Economy
# 14119                                                NaN            Elections
# 14120                                                NaN             Congress
# 14121                                                NaN             Religion
# 14122                                                NaN            Elections
# 14123                                                NaN            Elections
# 14124                                                NaN             Children
# 14125                                                NaN       Infrastructure
# 14126                                                NaN      City Government
# 14127                                                NaN                Crime
# 14128                                       U.S. Senator                Taxes
# 14129                                          President    Homeland Security
# 14130                                          President          Health Care
# 14131                Assistant to President Donald Trump                Taxes
# 14132                     former state land commissioner              Housing
# 14133                      Former sheriff, Dallas County                Crime
# 14134                                       U.S. Senator                Drugs
#
#                ruling        date edition_type binary_ruling
# 14085       Half-True  2017-12-01        State          True
# 14086           False  2017-11-07        State         False
# 14087     Mostly True  2017-12-06     National          True
# 14088           False  2017-12-05     National         False
# 14089       Half-True  2017-11-19        State          True
# 14090  Pants on Fire!  2017-12-03     National         False
# 14091  Pants on Fire!  2017-12-08     National         False
# 14092  Pants on Fire!  2017-12-05        Media         False
# 14093  Pants on Fire!  2017-12-06        Media         False
# 14094           False  2017-12-06        State         False
# 14095  Pants on Fire!  2017-11-13        Media         False
# 14096  Pants on Fire!  2017-12-08        Media         False
# 14097           False  2017-12-08     National         False
# 14098  Pants on Fire!  2017-12-01        State         False
# 14099           False  2017-12-08        Media         False
# 14100  Pants on Fire!  2017-12-08        Media         False
# 14101           False  2017-11-28        Media         False
# 14102    Mostly False  2017-12-08     National         False
# 14103  Pants on Fire!  2017-03-03        Media         False
# 14104  Pants on Fire!  2017-11-21        Media         False
# 14105  Pants on Fire!  2017-12-12        Media         False
# 14106     Mostly True  2017-12-10        State          True
# 14107    Mostly False  2017-12-04        State         False
# 14108     Mostly True  2017-10-30        State          True
# 14109    Mostly False  2017-06-15        State         False
# 14110           False  2017-12-10     National         False
# 14111    Mostly False  2017-12-03        State         False
# 14112       Half-True  2017-11-29        State          True
# 14113       Half-True  2017-11-30     National          True
# 14114  Pants on Fire!  2017-12-13        Media         False
# 14115       Half-True  2017-12-13        State          True
# 14116     Mostly True  2017-10-13        State          True
# 14117       Half-True  2017-10-19        State          True
# 14118           False  2017-11-29        State         False
# 14119  Pants on Fire!  2017-12-13        Media         False
# 14120  Pants on Fire!  2017-12-10        Media         False
# 14121           False  2017-12-09        Media         False
# 14122           False  2017-12-13     National         False
# 14123  Pants on Fire!  2017-12-15        Media         False
# 14124  Pants on Fire!  2016-09-20        Media         False
# 14125     Mostly True  2017-12-15        State          True
# 14126  Pants on Fire!  2017-12-16        Media         False
# 14127  Pants on Fire!  2017-12-11        State         False
# 14128       Half-True  2017-12-15        State          True
# 14129  Pants on Fire!  2017-12-15     National         False
# 14130           False  2017-12-20     National         False
# 14131           False  2017-12-21     National         False
# 14132     Mostly True  2017-12-08        State          True
# 14133       Half-True  2017-07-31        State          True
# 14134       Half-True  2017-11-22        State          True

# %% [markdown]
# Right now, the statement_context category is very difficult to interpret, because some of them are much more detailed than others (for instance, 'interview' versus 'an interview on WJAR-TV's "10 News Conference."')
#
# I'm going to try to create a new variable called 'simple_context' which eliminates some of that additional information to create clearer categories.

# %%
df['statement_context'].value_counts()
# Out:
# an interview                                                      333
# a news release                                                    319
# a tweet                                                           317
# a press release                                                   310
# a speech                                                          291
# a TV ad                                                           224
# a campaign ad                                                     170
# a television ad                                                   163
# a radio interview                                                 133
# a debate                                                          117
# a news conference                                                 111
# a press conference                                                108
# a Facebook post                                                   104
# a headline                                                        100
# a campaign commercial                                              93
# a television interview                                             84
# a speech.                                                          74
# a TV interview                                                     66
# a blog post                                                        61
# a TV ad.                                                           61
# a radio ad                                                         60
# a press release.                                                   57
# a chain e-mail                                                     52
# an interview on CNN                                                50
# an interview on Fox News                                           49
# an interview.                                                      48
# a campaign mailer                                                  48
# Internet posts                                                     47
# an interview on NBC's "Meet the Press"                             47
# a news release.                                                    46
#                                                                  ...
# a Dallas Morning News news story                                    1
# a speech at Rider University                                        1
# an op-ed in 'The Hill'                                              1
# an online petition and in a press release                           1
# Feb. 23, 2012, in a campaign ad                                     1
# an interview on The Kelly File                                      1
# an interview on Alex Jones' radio show                              1
# an interview on WJAR-TV's "10 News Conference."                     1
# a op-ed posted on his website                                       1
# a U.S. Senate campaign video ad                                     1
# an East Texas campaign stop.                                        1
# a town hall in Manchester, N.H.                                     1
# comments on the CNN debate                                          1
# the CNBC debate                                                     1
# Americans for Prosperity-Florida rally                              1
# Bill-signing ceremony                                               1
# his inaugural address                                               1
# a page on the White House website                                   1
# Atlanta Press Club speech                                           1
# an interview on "Morning Joe."                                      1
# Sean Hannity's show on Fox News                                     1
# a campaign fund-raising letter                                      1
# the GOP primary debate in Texas                                     1
# a rally speech                                                      1
# a politics column.                                                  1
# a round table discussion on Meet the Press                          1
# an episode of HBO's Real Sports with Bryant Gumbel                  1
# comments during the president's speech                              1
# a post on his campaign website about releasing his tax returns      1
# a radio interview with Democracy Now!                               1
# Name: statement_context, Length: 5452, dtype: int64

# %%
def simplifycontext(x):
    x = str(x)
    if 'interview' in x:
        y = 'an interview'
    elif 'news release' in x:
        y = 'a news release'
    elif 'press release' in x:
        y = 'a news release'
    elif 'campaign ad' in x:
        y = 'a campaign ad'
    elif 'speech' in x:
        y = 'a speech'
    elif 'debate' in x:
        y = 'a debate'
    elif 'news conference' in x:
        y = 'a news conference'
    elif 'press conference' in x:
        y = 'a news conference'
    elif 'TV ad' in x:
        y = 'a TV ad'
    elif 'op-ed' in x:
        y = 'an op-ed'
    elif 'inaugural' in x:
        y = 'speech'
    else: y = x
    return y 

df['simple_context'] = df['statement_context'].map(simplifycontext)

# %%
df['simple_context'].value_counts()
# Out:
# an interview                                                          2329
# a speech                                                              1404
# a debate                                                               960
# a news release                                                         903
# a TV ad                                                                394
# a news conference                                                      354
# a tweet                                                                317
# a campaign ad                                                          208
# an op-ed                                                               182
# a television ad                                                        163
# nan                                                                    114
# a Facebook post                                                        104
# a headline                                                             100
# a campaign commercial                                                   93
# a blog post                                                             61
# a radio ad                                                              60
# a chain e-mail                                                          52
# a campaign mailer                                                       48
# Internet posts                                                          47
# comments on ABC's "This Week"                                           45
# an ad                                                                   41
# a statement                                                             41
# a Web ad                                                                38
# a chain email                                                           37
# comments on "Fox News Sunday"                                           35
# an article                                                              33
# a campaign video                                                        33
# an email                                                                31
# a video                                                                 30
# an Internet post                                                        28
#                                                                       ...
# a round table discussion on Meet the Press                               1
# a politics column.                                                       1
# a campaign fund-raising letter                                           1
# Americans for Prosperity-Florida rally                                   1
# Sean Hannity's show on Fox News                                          1
# a statement by a spokesman                                               1
# the platform section of his campaign website                             1
# a video ad posted on his campaign website                                1
# GOP response to Obama's State of the Union                               1
# In a campaign mailer                                                     1
# comments during an appearance on 'The Rachel Maddow Show' on MSNBC       1
# in a web video.                                                          1
# a graphic released by his campaign                                       1
# 2013-14 veto message                                                     1
# an advertisement                                                         1
# a yard on Route 12 near Keene, N.H.                                      1
# a broadcast of the "Glenn Beck Program"                                  1
# an online commentary                                                     1
# TV niterview                                                             1
# on This Week with George Stephanopoulos                                  1
# a Joint Select Committee on Deficit Reduction hearing                    1
# a TV news show                                                           1
# a television/web ad                                                      1
# a comment on a "State of the State" TV program.                          1
# remarks in Coral Springs, Fla.                                           1
# a segment on "Morning Joe"                                               1
# a web video advertisement                                                1
# story in the Providence Journal                                          1
# testimony at a General Assembly pension hearing                          1
# testimony before the Senate Judiciary Committee                          1
# Name: simple_context, Length: 3345, dtype: int64

# %% [markdown]
# This has helped a little bit, but there's just so many different unique contexts that I think it will be very time-consuming to properly classify all of them. I may revisit this at a later date if it seems like there may be some interesting relationships within this category.
#
# There are similar problems with the speaker_job field, which I will try to address below with the same approach.

# %%
df['speaker_job'].value_counts()
# Out:
# President                                                                 1084
# U.S. Senator                                                               641
# Governor                                                                   333
# U.S. senator                                                               325
# Presidential candidate                                                     312
# U.S. Representative                                                        233
# Senator                                                                    221
# Former governor                                                            206
# Milwaukee County Executive                                                 182
# U.S. Energy Secretary                                                      171
# State Senator                                                              148
# U.S. representative                                                        141
# U.S. House of Representatives                                              132
# Congressman                                                                112
# Attorney                                                                   110
# State Representative                                                       104
# Governor of New Jersey                                                     102
# Social media posting                                                        99
# State representative                                                        92
# U.S. Congressman                                                            82
# Speaker of the House of Representatives                                     73
# Congresswoman                                                               66
# Governor of Ohio as of Jan. 10, 2011                                        64
# State senator                                                               63
# state senator                                                               62
# governor                                                                    57
# Candidate for U.S. Senate and physician                                     55
# state representative                                                        53
# U.S. Representative, Florida District 23                                    48
# U.S. senator from Ohio                                                      48
#                                                                           ...
# Staff writer for The New Yorker                                              1
# Portland City Commissioner                                                   1
# United States Senator                                                        1
# Editorial board member, Wall Street Journal                                  1
# President, Citizens for Community Values                                     1
# XX                                                                           1
# liberal advocacy organization                                                1
# Chair of the president's Council of Economic Advisers                        1
# Director, Sustainable Water Infrastructure Program, Ceres                    1
# President of NARAL Pro-Choice America                                        1
# Virginia director of Americans for Prosperity                                1
# Weekly newsmagazine                                                          1
# Senior fellow at the Ethics and Public Policy Center                         1
# Executive director of the Ohio Association of Second Harvest Foodbanks       1
# Commissioner of education                                                    1
# administrator, Rhode Island chapter, Gun Rights Across America.              1
# Precinct 4 Commissioner                                                      1
# letter writer                                                                1
# Trade organization                                                           1
# Mayor of Dallas, Texas                                                       1
# CEO, Rhode Island Public Transit Autority                                    1
# Dougherty County District Attorney                                           1
# Providence City Councilman                                                   1
# Politico editorial cartoonist                                                1
# Emory University Food Service Administration director                        1
# Co-owner, Huffines Communities                                               1
# Director of Environmental Planning, Atlanta Regional Commission              1
# None                                                                         1
# promoting approval of financing for Sun Life Stadium                         1
# Executive director of the 1851 Center for Constitutional Law                 1
# Name: speaker_job, Length: 1439, dtype: int64

# %%
def simplifyjob(x):
    x = str(x)
    if 'u.s. senator' in x.lower(): y='U.S. Senator'
    elif 'united states senator' in x.lower(): y='U.S. Senator'
    elif x.lower()=='senator': y='U.S. Senator'
    elif 'u.s. representative' in x.lower(): y='U.S. Representative'
    elif 'congressman' in x.lower(): y='U.S. Representative'
    elif 'congresswoman' in x.lower(): y='U.S. Representative'
    elif 'u.s. house' in x.lower(): y='U.S. Representative'
    elif 'member of congress' in x.lower(): y='U.S. Representative'
    elif 'state representative' in x.lower(): y='State Representative'
    elif 'state senator' in x.lower(): y='State Senator'
    elif 'governor' in x.lower(): y='Governor'
    elif 'lawyer' in x.lower(): y='Lawyer'
    elif 'political action committee'==x.lower(): y='Political Action Committee'
    elif 'pac'==x.lower(): y='Political Action Committee'
    elif 'super pac'==x.lower(): y='Political Action Committee'
    elif 'state assembly' in x.lower(): y='State Assembly Member'
    else: y = x
    return y

df['simple_job'] = df['speaker_job'].map(simplifyjob)

# %%
df['simple_job'].value_counts()
# Out:
# nan                                                                          4133
# U.S. Senator                                                                 1246
# U.S. Representative                                                          1135
# President                                                                    1084
# Governor                                                                     1018
# State Senator                                                                 330
# Presidential candidate                                                        312
# State Representative                                                          271
# Milwaukee County Executive                                                    182
# U.S. Energy Secretary                                                         171
# Attorney                                                                      110
# Social media posting                                                           99
# State Assembly Member                                                          96
# Speaker of the House of Representatives                                        73
# Lawyer                                                                         67
# Political Action Committee                                                     59
# Candidate for U.S. Senate and physician                                        55
# Businessman                                                                    45
# author                                                                         44
# House Majority Leader                                                          43
# former president                                                               41
# Radio host                                                                     40
# House Minority Leader                                                          37
# Secretary of State                                                             37
# Columnist                                                                      35
# consultant                                                                     35
# Madison school board member                                                    34
# Attorney General                                                               33
# Ohio treasurer                                                                 31
# Senate minority leader                                                         30
#                                                                              ...
# Trade organization                                                              1
# Mayor of Dallas, Texas                                                          1
# CEO, Rhode Island Public Transit Autority                                       1
# Conservative Political Group                                                    1
# vice president Spectra Energy                                                   1
# The public-private economic development agency                                  1
# managing director, Quonset Business Park                                        1
# Northeast regional spokesman, National Republican Congressional Committee       1
# Jefferson County District Attorney                                              1
# Talks show host                                                                 1
# psychiatrist                                                                    1
# Head swim coach                                                                 1
# CEO, California High-Speed Rail Authority                                       1
# Olympic medalist                                                                1
# Memphis police union                                                            1
# Altria spokesman                                                                1
# State treasurer                                                                 1
# ceo                                                                             1
# Bexar County judge                                                              1
# RT correspondent                                                                1
# Unknown                                                                         1
# CEO of CKE Restaurants                                                          1
# safety program                                                                  1
# Cardinal                                                                        1
# PETA writer                                                                     1
# Milwaukee County Supervisor                                                     1
# retired police captain                                                          1
# singer/activist                                                                 1
# president, Texans for Life Coalition                                            1
# Interim president and CEO                                                       1
# Name: simple_job, Length: 1276, dtype: int64

# %% [markdown]
# Again, this has helped slightly, but there are still an awful lot of unique entries in this field.  Further work may be necessary to generalize further.

# %% [markdown]
# Finally: 'date' is a field that should not be a string object, but rather a datetime object, so I'll finish this cleaning by converting that column below.

# %%
df['date'] = pd.to_datetime(df['date'],infer_datetime_format=True)

# %%
df.dtypes
# Out:
# edition                      object
# statement                    object
# statement_type               object
# statement_context            object
# speaker                      object
# speaker_party                object
# speaker_job                  object
# subject                      object
# ruling                       object
# date                 datetime64[ns]
# edition_type                 object
# binary_ruling                object
# simple_context               object
# simple_job                   object
# dtype: object

# %%
dfcopy = df.copy()
dfcopy.sort_values('date').head()
# Out:
#        edition                                          statement  \
# 2693   Georgia  The economic impact of Atlanta's 2000 Super Bo...
# 3069   Florida  "Financed the largest parking expansion progra...
# 22    National  "The failings in our civil service are encoura...
# 12    National  "(McCain) said he was opposed to overturning R...
# 11    National  "Senator McCain voted against the Bush tax cut...
#
#      statement_type                                  statement_context  \
# 2693          Claim                                            a study
# 3069          Claim  city report reprinted as 2011 mayoral campaign...
# 22            Claim                                     Oklahoma City.
# 12           Attack                                     Stratham, N.H.
# 11           Attack                                     Stratham, N.H.
#
#                       speaker speaker_party      speaker_job         subject  \
# 2693   Atlanta Sports Council          None              NaN         Economy
# 3069               Dick Greco          None              NaN     City Budget
# 22                John McCain    Republican     U.S. senator  Federal Budget
# 12                Mitt Romney    Republican  Former governor        Abortion
# 11                Mitt Romney    Republican  Former governor           Taxes
#
#             ruling       date edition_type binary_ruling  \
# 2693         False 2000-10-01        State         False
# 3069  Mostly False 2002-05-01        State         False
# 22     Mostly True 2007-03-21     National          True
# 12       Half-True 2007-04-26     National          True
# 11            True 2007-04-26     National          True
#
#                                          simple_context    simple_job
# 2693                                            a study           nan
# 3069  city report reprinted as 2011 mayoral campaign...           nan
# 22                                       Oklahoma City.  U.S. Senator
# 12                                       Stratham, N.H.      Governor
# 11                                       Stratham, N.H.      Governor

# %%
dfcopy.sort_values('date').tail()
# Out:
#           edition                                          statement  \
# 14129    National  Says of the diversity visa lottery program, "t...
# 14123  PunditFact  "Alabama state police arrest 3 poll workers in...
# 14126  PunditFact  "Breaking: Muslim New Jersey Mayor just banned...
# 14130    National  "We essentially repealed Obamacare because we ...
# 14131    National  In April, "the vast majority will be (filling ...
#
#       statement_type                statement_context  \
# 14129          Claim                         a speech
# 14123          Claim                       a headline
# 14126         Attack                       a headline
# 14130          Claim                         a speech
# 14131          Claim  an interview on "Fox & Friends"
#
#                          speaker speaker_party  \
# 14129               Donald Trump    Republican
# 14123        American Revolution          None
# 14126   TheLastLineOfDefense.org          None
# 14130               Donald Trump    Republican
# 14131               Ivanka Trump          None
#
#                                speaker_job            subject          ruling  \
# 14129                            President  Homeland Security  Pants on Fire!
# 14123                                  NaN          Elections  Pants on Fire!
# 14126                                  NaN    City Government  Pants on Fire!
# 14130                            President        Health Care           False
# 14131  Assistant to President Donald Trump              Taxes           False
#
#             date edition_type binary_ruling simple_context  \
# 14129 2017-12-15     National         False       a speech
# 14123 2017-12-15        Media         False     a headline
# 14126 2017-12-16        Media         False     a headline
# 14130 2017-12-20     National         False       a speech
# 14131 2017-12-21     National         False   an interview
#
#                                 simple_job
# 14129                            President
# 14123                                  nan
# 14126                                  nan
# 14130                            President
# 14131  Assistant to President Donald Trump

# %% [markdown]
# ### Task 3: Describe your data: keep your intended audience(s) in mind.
#    - Document your work so far in a Jupyter notebook.

# %%
df.isnull().sum()
# Out:
# edition                 0
# statement               0
# statement_type          0
# statement_context     114
# speaker                 0
# speaker_party           0
# speaker_job          4133
# subject                 0
# ruling                  0
# date                    0
# edition_type            0
# binary_ruling           0
# simple_context          0
# simple_job              0
# dtype: int64

# %%
df['statement_type'].value_counts()
# Out:
# Claim     12335
# Attack     1570
# Name: statement_type, dtype: int64

# %%
df['speaker'].value_counts()
# Out:
# Barack Obama                                    598
# Donald Trump                                    481
# Hillary Clinton                                 295
#  Bloggers                                       238
# Mitt Romney                                     206
# John McCain                                     184
# Scott Walker                                    182
#  Chain email                                    180
# Rick Perry                                      171
# Marco Rubio                                     154
# Rick Scott                                      148
# Ted Cruz                                        123
# Bernie Sanders                                  118
# Chris Christie                                  102
#  Facebook posts                                  99
# Paul Ryan                                        83
# Newt Gingrich                                    82
# Charlie Crist                                    80
# Jeb Bush                                         80
# Joe Biden                                        75
# John Boehner                                     69
# Sarah Palin                                      64
# John Kasich                                      64
# Rick Santorum                                    61
# Michele Bachmann                                 61
# Rand Paul                                        55
#  National Republican Congressional Committee     53
# Ron Johnson                                      51
# Tim Kaine                                        51
# Greg Abbott                                      50
#                                                ...
# Thomas Sgouros Jr.                                1
# Jeff Wagner                                       1
# Maria Cardona                                     1
# Marc Thiessen                                     1
# Nancy Jester                                      1
# Ben Nelson                                        1
# Usain Bolt                                        1
#  Turn Right USA                                   1
# Kathleen Murphy                                   1
# John Kennedy                                      1
# Rob Eissler                                       1
#  Oregon League of Conservation Voters             1
# Talmadge Heflin                                   1
#  The Coalition for Public Schools                 1
# Ed Doyle                                          1
#  TheNewYorkEvening.com                            1
# Debbie Jackow                                     1
# Dan Lungren                                       1
# New York Post                                     1
#  Yes on 82 and 83 campaign                        1
# Michael Medved                                    1
#  Newsmax                                          1
# Amy Handlin                                       1
# Joe Wilkinson                                     1
# Eric Gray                                         1
# Justin Trudeau                                    1
#  Protect Your Vote                                1
# Vincent Prieto                                    1
# Xi Jinping                                        1
#  The Freedom Project                              1
# Name: speaker, Length: 3650, dtype: int64

# %%
df['speaker_party'].value_counts()
# Out:
# Republican                         6097
# Democrat                           4354
# None                               2582
# Organization                        285
# Independent                         197
# Newsmaker                            66
# Libertarian                          60
# Journalist                           52
# Activist                             49
# Columnist                            47
# Talk show host                       33
# State official                       27
# Labor leader                         17
# Business leader                      11
# Tea Party member                     10
# Green                                 3
# Constitution Party                    3
# Education official                    3
# Government body                       2
# county commissioner                   2
# Moderate Party                        1
# Ocean State Tea Party in Action       1
# Democratic Farmer-Labor               1
# Law enforcement official              1
# Liberal Party of Canada               1
# Name: speaker_party, dtype: int64

# %%
df['subject'].value_counts()
# Out:
# Economy                          1173
# Health Care                      1036
# Candidate Biography               757
# Education                         745
# Elections                         570
# Federal Budget                    494
# Crime                             493
# Taxes                             424
# Foreign Policy                    415
# Immigration                       414
# Abortion                          330
# Energy                            326
# State Budget                      255
# Jobs                              245
# Guns                              244
# Campaign Finance                  236
# Children                          226
# Fake news                         216
# Congress                          205
# Corrections and Updates           197
# Deficit                           186
# Environment                       164
# History                           161
# Corporations                      141
# Job Accomplishments               139
# Climate Change                    137
# Civil Rights                      132
# Ethics                            124
# Bipartisanship                    114
# Debt                              110
#                                  ...
# Marriage                            8
# Water                               8
# Gas Prices                          8
# Weather                             7
# Food                                7
# Natural Disasters                   7
# Florida Amendments                  7
# Hunger                              6
# New Hampshire 2012                  6
# Science                             6
# Wealth                              5
# Message Machine 2014                5
# Kagan Nomination                    5
# Privacy                             5
# Death Penalty                       5
# Sexuality                           5
# After the Fact                      5
# Lottery                             4
# Occupy Wall Street                  4
# Autism                              4
# State government spending           4
# This Week - ABC News                2
# workers' compensation               2
# Iran                                1
# Automatic Voter Registration        1
# Urban                               1
# Fires                               1
# Driver's licenses                   1
# Homeless                            1
# Nightlife                           1
# Name: subject, Length: 146, dtype: int64

# %% [markdown]
# The data that I'm working with is a collection of statements from (mostly) American public figures, along with information about the speaker, the context of the statement, and the true/false rating the statement received from Politifact. (Refer to the data dictionary above for a more detailed explanation of the fields.)
#
# The Politifact ruling will be my target variable in this investigation.  There are six different rulings, ranging from 'True' for the most veracious statements to 'Pants on Fire!' for the most egregious lies. Most of the ruling categories have roughly comparable numbers of observations (between 2100 and 2800), except for 'Pants on Fire!', which has 1350.  When the top three rulings are bundled together as 'True' and the bottom three rulings are bundled together as 'False', there are 7600 True statements and 6300 False statements -- so, reasonably balanced.  (This relieves one of my concerns, which was that Politifact would be mostly looking to research statements which seem fishy or controversial to begin with, and that I wouldn't therefore have sufficient 'True' observations to train my model with.  I'm glad that doesn't seem to be the case!)
#
# A majority of my observations (around 8000) come from state editions of Politifact, and then roughly 5000 come from the national edition.  A further 1000 come from editions focused on the media or international events/figures.
#
# The vast majority of my observations (12300) are Claims, with a further 1600 Attacks.
#
# The statement_context variable is tricky, because Politifact seems to have wildly different approaches about how specific this field should be. I've done some work towards generalizing some of the overly-specific contexts, and this is recorded as simple_context in my dataframe.  However, this isn't extremely helpful at the moment, because there are still far too many unique entries.  Generally though, we can see that the statements have been pulled from a wide variety of sources -- speeches, interviews, twitter feeds, campaign materials, debates, articles, and more. Also, note that 114 observations are missing the context.
#
# Statements are from a wide variety of speakers, but we can see that prominent politicians from the last three presidential election cycles (presidential candidates and their vice presidential candidates especially) are particularly well-represented.  Additionally, some of the speakers are not individuals at all, but rather organizations or groups of people like the Republican National Committee or 'Bloggers'.
#
# The majority of speakers are either Democrat, Republican, or None. These together account for roughly 13 out of every 14 observations.
#
# The speaker_job variable has similar problems to the statement_context field.  Many of the observations (around 4000) do not have this information recorded.  Of those that do, the most frequent jobs are those with national political prominence: the president, members of the US House and US Senate, and governors.
#
# The subject variable indicates the topic of the statement being assessed, and we can see that there are a wide variety of subjects that Politifact reports on.  The most common topics are the economy and healthcare, which reflects the prominence of these two subjects in the national political debate.
#
# The dates of these statements range from 2000 through to December 2017. However, there are only two observations from before 2007, since Politifact really started its work during the primaries for the 2008 presidential election.

# %% [markdown]
# ### Task 4: Document your project goals (revise from your initial pitch)
#    - Articulate specific aims
#    - Outline proposed methods and models
#    - Define risks & assumptions

# %% [markdown]
# #### Specific aims:
#
# I will be trying to see whether I can predict the truthfulness of a statement from the information that I've collected from Politifact.
#
# I would also like to identify what features are helpful in predicting truthfulness.  At a minimum, I'll be investigating the relationship between the truthfulness of a statement and:
# - the identity of the speaker
# - the political affiliation of the speaker
# - the topic of the statement
# - the nature of the statement (Claim vs Attack)
# - the language used in the statement

# %% [markdown]
# #### Proposed methods and models:
#
# This will be a classification problem (although I could potentially use regression models if I turn ruling variable into a number from 1 to 6? I don't think this makes sense, though -- it would still be an ordinal scale where we don't know if the difference between 1 and 2 (ie Pants on Fire! to False) is the same as the difference between 2 and 3 (ie False to Mostly False)).
#
# I will be using some NLP to help investigate the relationship between the language used in the statement and the statement's truthfulness, so the first step will be to use a vectorizer to obtain the language features.
#
# I will also have to do some EDA to get a better sense of what features may be predictive of truthfulness from those I already have in my dataframe (political affiliation, for example).
#
# Then, I will use variety of classification models from those that we've learned (logistic regression, k-nearest neighbors, support vector classification, decision trees, ensemble methods like random forest or bagging classifiers, etc) and find the best model for accurately predicting truthfulness.
#
# I will evaluate the success of my model on the basis of its accuracy as well as its precision.  (Here, I'm defining a true positive as correctly predicting a lie.)  Precision is important to me in this case because having a high proportion of true 'Lies' out of all predicted 'Lies' would enable journalists for example to use this model to get a good list of leads to follow if they're trying to hold lying politicians to account.  I think it's probably more useful to be pretty confident that the 'Lies' the model identifies are probably lies than to be confident that we've caught all of the lies (because with politicians, that would NEVER be possible anyway, since they lie as easily as they breathe).  If a journalist had to take a lot of time researching statements that ended up being true, it might not be very useful.

# %% [markdown]
# #### Risks and assumptions:
#
# Some of my assumptions are:
# - The Politifact writers are impartial and good at their jobs, so their ratings will be fair and accurate across different subjects, speakers, years, political affiliations, etc., and these ratings will be consistent from one Politifact writer to another.
# - Half-True is actually more true than false, so these statements should be grouped in as broadly 'True'.
# - The statements selected by Politifact to evaluate are roughly representative of political statements generally (ie, they are not selected because they sound suspicious or sensational, but are in fact typical of the national political debate).

# %%
df.to_csv('cleaned_politifact_df',encoding='utf-8')
